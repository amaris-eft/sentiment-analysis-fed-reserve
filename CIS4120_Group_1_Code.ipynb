# %%
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %%
import pandas as pd
import numpy as np
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
import nltk
from nltk.tokenize import word_tokenize
from nltk.tokenize import sent_tokenize
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/taohidshadat/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
# load data
speeches = pd.read_csv('speeches.csv')
nasdaq = pd.read_csv('^IXIC.csv')
sp500 = pd.read_csv('^GSPC.csv')

# %%
speeches.head()
# Out:
#         Date                                               Link  \
# 0  2/11/2020  https://www.federalreserve.gov/newsevents/test...
# 1   4/9/2020  https://www.federalreserve.gov/newsevents/test...
# 2  5/12/2020  https://www.federalreserve.gov/newsevents/test...
# 3  5/13/2020  https://www.federalreserve.gov/newsevents/spee...
# 4  5/19/2020  https://www.federalreserve.gov/newsevents/test...
#
#                                               speech
# 0  Chair Powell submitted identical remarks to th...
# 1  Good morning. The challenge we face today is d...
# 2  Chairman Crapo, Ranking Member Brown, members ...
# 3  The coronavirus has left a devastating human a...
# 4  Chairman Crapo, Ranking Member Brown, and othe...

# %%
nasdaq.head()
# Out:
#         Date         Open         High          Low        Close    Adj Close  \
# 0  2/10/2020     9,493.63     9,628.66     9,493.63     9,628.39     9,628.39
# 1  2/11/2020     9,680.89     9,714.74     9,617.21     9,638.94     9,638.94
# 2  2/12/2020     9,688.60     9,728.77     9,666.69     9,725.96     9,725.96
# 3   4/8/2020  7975.720215  8114.430176  7901.939941  8090.899902  8090.899902
# 4   4/9/2020  8169.009766  8227.910156  8072.319824  8153.580078  8153.580078
#
#          Volume
# 0  2,187,520,000
# 1  2,450,070,000
# 2  2,366,510,000
# 3  3,487,440,000
# 4  4,145,460,000

# %%
sp500.head()
# Out:
#         Date      Open      High       Low    Close* Adj Close         Volume
# 0  2/10/2020  3,318.28  3,352.26  3,317.77  3,352.09  3,352.09  3,462,730,000
# 1  2/11/2020  3,365.87  3,375.63  3,352.72  3,357.75  3,357.75  3,762,940,000
# 2  2/12/2020  3,370.50  3,381.47  3,369.72  3,379.45  3,379.45  3,930,910,000
# 3   4/8/2020  2,685.00  2,760.75  2,663.30  2,749.98  2,749.98  5,875,710,000
# 4   4/9/2020  2,776.99  2,818.57  2,762.36  2,789.82  2,789.82  7,899,550,000

# %%
# Converting all date columns to date type
speeches['Date'] = pd.to_datetime(speeches['Date'])
sp500['Date'] = pd.to_datetime(sp500['Date'])
nasdaq['Date'] = pd.to_datetime(nasdaq['Date'])

# %%
# stripping all commas
nasdaq = nasdaq.applymap(lambda x: x.replace(',', '') if isinstance(x, str) else x)

# %%
# stripping all commas
sp500 = sp500.applymap(lambda x: x.replace(',', '') if isinstance(x, str) else x)

# %%
# converting all columns but date column to float type
nasdaq.loc[:, nasdaq.select_dtypes(include=[object]).columns] = nasdaq.select_dtypes(include=[object]).astype(float)

# %%
# converting all columns but date column to float type
sp500.loc[:, sp500.select_dtypes(include=[object]).columns] = sp500.select_dtypes(include=[object]).astype(float)

# %%
# calculating percent change of Open and Close
nasdaq['Pct_Change'] = ((nasdaq['Adj Close'] - nasdaq['Open']) / (nasdaq['Open'])) * 100

# %%
# calculating percent change of Open and Close
sp500['Pct_Change'] = ((sp500['Adj Close'] - sp500['Open']) / (sp500['Open'])) * 100

# %%
# prefixing column names
sp500_prefix = sp500[sp500.columns.drop('Date')].add_prefix('sp500_')
sp500 = pd.concat([sp500['Date'], sp500_prefix], axis=1)
nasdaq_prefix = nasdaq[nasdaq.columns.drop('Date')].add_prefix('nasdaq_')
nasdaq = pd.concat([nasdaq['Date'], nasdaq_prefix], axis=1)

# %%
# initializng Vader Sentiment
analyzer = SentimentIntensityAnalyzer()

# %%
# get speech scores
speeches['Speech_Scores'] = speeches['speech'].apply(lambda x: analyzer.polarity_scores(x))

# %%
speeches.head()
# Out:
#         Date                                               Link  \
# 0 2020-02-11  https://www.federalreserve.gov/newsevents/test...
# 1 2020-04-09  https://www.federalreserve.gov/newsevents/test...
# 2 2020-05-12  https://www.federalreserve.gov/newsevents/test...
# 3 2020-05-13  https://www.federalreserve.gov/newsevents/spee...
# 4 2020-05-19  https://www.federalreserve.gov/newsevents/test...
#
#                                               speech  \
# 0  Chair Powell submitted identical remarks to th...
# 1  Good morning. The challenge we face today is d...
# 2  Chairman Crapo, Ranking Member Brown, members ...
# 3  The coronavirus has left a devastating human a...
# 4  Chairman Crapo, Ranking Member Brown, and othe...
#
#                                        Speech_Scores
# 0  {'neg': 0.051, 'neu': 0.796, 'pos': 0.153, 'co...
# 1  {'neg': 0.08, 'neu': 0.747, 'pos': 0.172, 'com...
# 2  {'neg': 0.106, 'neu': 0.745, 'pos': 0.149, 'co...
# 3  {'neg': 0.126, 'neu': 0.754, 'pos': 0.12, 'com...
# 4  {'neg': 0.078, 'neu': 0.756, 'pos': 0.166, 'co...

# %%
# function to get sentiment of speech
def get_sentiment(speech):
    scores = analyzer.polarity_scores(speech)
    score = scores['compound']
    if score >= 0.5:
        return 'Positive'
    elif score < 0.5 and score >= -0.5:
        return 'Neutral'
    else:
        return 'Negative'
    
speeches['Speech_Sentiment'] = speeches['speech'].apply(get_sentiment)

# %%
speeches.head()
# Out:
#         Date                                               Link  \
# 0 2020-02-11  https://www.federalreserve.gov/newsevents/test...
# 1 2020-04-09  https://www.federalreserve.gov/newsevents/test...
# 2 2020-05-12  https://www.federalreserve.gov/newsevents/test...
# 3 2020-05-13  https://www.federalreserve.gov/newsevents/spee...
# 4 2020-05-19  https://www.federalreserve.gov/newsevents/test...
#
#                                               speech  \
# 0  Chair Powell submitted identical remarks to th...
# 1  Good morning. The challenge we face today is d...
# 2  Chairman Crapo, Ranking Member Brown, members ...
# 3  The coronavirus has left a devastating human a...
# 4  Chairman Crapo, Ranking Member Brown, and othe...
#
#                                        Speech_Scores Speech_Sentiment
# 0  {'neg': 0.051, 'neu': 0.796, 'pos': 0.153, 'co...         Positive
# 1  {'neg': 0.08, 'neu': 0.747, 'pos': 0.172, 'com...         Positive
# 2  {'neg': 0.106, 'neu': 0.745, 'pos': 0.149, 'co...         Positive
# 3  {'neg': 0.126, 'neu': 0.754, 'pos': 0.12, 'com...         Negative
# 4  {'neg': 0.078, 'neu': 0.756, 'pos': 0.166, 'co...         Positive

# %%
# define function to find the most positive and negative sentences in a speech
def find_most_positive_and_negative_sentences(speech):
    # split the speech into sentences
    sentences = nltk.sent_tokenize(speech)

    # initialize variables to store the most positive and negative sentences
    most_positive = {'sentence': '', 'score': -1}
    most_negative = {'sentence': '', 'score': 1}

    # iterate over each sentence and compute the sentiment score
    for sentence in sentences:
        # compute the sentiment score using VADER
        score = analyzer.polarity_scores(sentence)['compound']

        # check if the current sentence has the most positive or negative score
        if score > most_positive['score']:
            most_positive['score'] = score
            most_positive['sentence'] = sentence
        elif score < most_negative['score']:
            most_negative['score'] = score
            most_negative['sentence'] = sentence

    # return the most positive and negative sentences
    return most_positive['sentence'], most_negative['sentence']

speeches[['Most positive sentence', 'Most negative sentence']] = speeches['speech'].apply(
                        find_most_positive_and_negative_sentences).apply(pd.Series)

# %%
speeches.head()
# Out:
#         Date                                               Link  \
# 0 2020-02-11  https://www.federalreserve.gov/newsevents/test...
# 1 2020-04-09  https://www.federalreserve.gov/newsevents/test...
# 2 2020-05-12  https://www.federalreserve.gov/newsevents/test...
# 3 2020-05-13  https://www.federalreserve.gov/newsevents/spee...
# 4 2020-05-19  https://www.federalreserve.gov/newsevents/test...
#
#                                               speech  \
# 0  Chair Powell submitted identical remarks to th...
# 1  Good morning. The challenge we face today is d...
# 2  Chairman Crapo, Ranking Member Brown, members ...
# 3  The coronavirus has left a devastating human a...
# 4  Chairman Crapo, Ranking Member Brown, and othe...
#
#                                        Speech_Scores Speech_Sentiment  \
# 0  {'neg': 0.051, 'neu': 0.796, 'pos': 0.153, 'co...         Positive
# 1  {'neg': 0.08, 'neu': 0.747, 'pos': 0.172, 'com...         Positive
# 2  {'neg': 0.106, 'neu': 0.745, 'pos': 0.149, 'co...         Positive
# 3  {'neg': 0.126, 'neu': 0.754, 'pos': 0.12, 'com...         Negative
# 4  {'neg': 0.078, 'neu': 0.756, 'pos': 0.166, 'co...         Positive
#
#                               Most positive sentence  \
# 0  This low interest rate environment may limit t...
# 1  Even more importantly, we have acted to safegu...
# 2  Over the past two months, the Federal Reserve ...
# 3  And fourth, temporary regulatory adjustments t...
# 4  In addition to monetary policy, we took forcef...
#
#                               Most negative sentence
# 0  Residential investment turned up in the second...
# 1  The coronavirus has spread quickly around the ...
# 2  More than a decade ago, U.S. banking organizat...
# 3  The scope and speed of this downturn are witho...
# 4  By these measures and many others, the scope a...

# %%
# using sumy to summarize the speech to understand it better
#!pip install sumy
from sumy.parsers.plaintext import PlaintextParser
from sumy.nlp.tokenizers import Tokenizer
from sumy.summarizers.text_rank import TextRankSummarizer

# %%
def summarize_speech(text):
    # Set the number of sentences in the summary
    num_sentences = 1

    # Initialize the TextRank summarizer
    summarizer = TextRankSummarizer()

    # Parse the text and tokenize it
    parser = PlaintextParser.from_string(text, Tokenizer("english"))

    # Generate the summary and join the sentences
    summary = " ".join([str(sentence) for sentence in summarizer(parser.document, num_sentences)])

    # return the summary
    return summary

# %%
# applying function
speeches['Summary'] = speeches['speech'].apply(summarize_speech)

# %%
# applying function
speeches['Summary_Sentiment'] = speeches['Summary'].apply(get_sentiment)

# %%
# combining all data together
df = pd.merge(speeches, nasdaq[['Date','nasdaq_Pct_Change']], how = 'left', on = 'Date')
df = pd.merge(df, sp500[['Date','sp500_Pct_Change']], how = 'left', on = 'Date')

# %%
df
# Out:
#          Date                                               Link  \
# 0  2020-02-11  https://www.federalreserve.gov/newsevents/test...
# 1  2020-04-09  https://www.federalreserve.gov/newsevents/test...
# 2  2020-05-12  https://www.federalreserve.gov/newsevents/test...
# 3  2020-05-13  https://www.federalreserve.gov/newsevents/spee...
# 4  2020-05-19  https://www.federalreserve.gov/newsevents/test...
# 5  2020-05-21  https://www.federalreserve.gov/newsevents/spee...
# 6  2020-06-16  https://www.federalreserve.gov/newsevents/test...
# 7  2020-06-19  https://www.federalreserve.gov/newsevents/spee...
# 8  2020-06-30  https://www.federalreserve.gov/newsevents/test...
# 9  2020-08-27  https://www.federalreserve.gov/newsevents/spee...
# 10 2020-09-22  https://www.federalreserve.gov/newsevents/test...
# 11 2020-10-06  https://www.federalreserve.gov/newsevents/spee...
# 12 2020-11-10  https://www.federalreserve.gov/newsevents/test...
# 13 2020-12-01  https://www.federalreserve.gov/newsevents/test...
#
#                                                speech  \
# 0   Chair Powell submitted identical remarks to th...
# 1   Good morning. The challenge we face today is d...
# 2   Chairman Crapo, Ranking Member Brown, members ...
# 3   The coronavirus has left a devastating human a...
# 4   Chairman Crapo, Ranking Member Brown, and othe...
# 5   Good afternoon. I just want to say a few words...
# 6   Chair Powell submitted identical remarks to th...
# 7   Thank you, President Mester and Treye Johnson,...
# 8   Chairwoman Waters, Ranking Member McHenry, and...
# 9   Thank you, Esther, for that introduction, and ...
# 10  Chair Powell submitted identical remarks to th...
# 11  Good morning. It has been just eight months si...
# 12  Vice Chair for Supervision Quarles submitted i...
# 13  Chair Powell submitted identical remarks to th...
#
#                                         Speech_Scores Speech_Sentiment  \
# 0   {'neg': 0.051, 'neu': 0.796, 'pos': 0.153, 'co...         Positive
# 1   {'neg': 0.08, 'neu': 0.747, 'pos': 0.172, 'com...         Positive
# 2   {'neg': 0.106, 'neu': 0.745, 'pos': 0.149, 'co...         Positive
# 3   {'neg': 0.126, 'neu': 0.754, 'pos': 0.12, 'com...         Negative
# 4   {'neg': 0.078, 'neu': 0.756, 'pos': 0.166, 'co...         Positive
# 5   {'neg': 0.034, 'neu': 0.844, 'pos': 0.122, 'co...         Positive
# 6   {'neg': 0.064, 'neu': 0.782, 'pos': 0.154, 'co...         Positive
# 7   {'neg': 0.109, 'neu': 0.759, 'pos': 0.132, 'co...         Positive
# 8   {'neg': 0.059, 'neu': 0.765, 'pos': 0.176, 'co...         Positive
# 9   {'neg': 0.059, 'neu': 0.826, 'pos': 0.115, 'co...         Positive
# 10  {'neg': 0.029, 'neu': 0.825, 'pos': 0.145, 'co...         Positive
# 11  {'neg': 0.072, 'neu': 0.817, 'pos': 0.111, 'co...         Positive
# 12  {'neg': 0.068, 'neu': 0.788, 'pos': 0.144, 'co...         Positive
# 13  {'neg': 0.027, 'neu': 0.845, 'pos': 0.128, 'co...         Positive
#
#                                Most positive sentence  \
# 0   This low interest rate environment may limit t...
# 1   Even more importantly, we have acted to safegu...
# 2   Over the past two months, the Federal Reserve ...
# 3   And fourth, temporary regulatory adjustments t...
# 4   In addition to monetary policy, we took forcef...
# 5   But all of us have our own decisions to make a...
# 6   To support the small business sector, we estab...
# 7   But given the opportunity, I'll always bet on ...
# 8   In addition to these steps, we took forceful m...
# 9   This emphasis on transparency reflected what w...
# 10  With funding from the CARES Act (Coronavirus A...
# 11  On a more positive note, we have seen that the...
# 12  Since then, working with our colleagues in oth...
# 13  With funding from the Coronavirus Aid, Relief,...
#
#                                Most negative sentence  \
# 0   Residential investment turned up in the second...
# 1   The coronavirus has spread quickly around the ...
# 2   More than a decade ago, U.S. banking organizat...
# 3   The scope and speed of this downturn are witho...
# 4   By these measures and many others, the scope a...
# 5   And while the burden is widespread, it is not ...
# 6   I want to end by acknowledging the tragic even...
# 7   A particular cruelty of the pandemic has been ...
# 8   In contrast to the 2008 crisis when banks pull...
# 9   Having declined significantly in the five year...
# 10  Main Street loans have a five-year maturity, n...
# 11  By the end of the month, many important market...
# 12  But in light of continuing uncertainty, we too...
# 13  In contrast, spending on services remains low ...
#
#                                               Summary Summary_Sentiment  \
# 0   Over the second half of 2019, the FOMC shifted...           Neutral
# 1   Many of the programs we are undertaking to sup...          Positive
# 2   We advised institutions that working construct...          Positive
# 3   Long stretches of unemployment can damage or e...          Negative
# 4   In addition to monetary policy, we took forcef...          Positive
# 5   From an economic perspective, we hope to learn...           Neutral
# 6   To provide stability to the financial system a...          Positive
# 7   And employers' input has influenced work acros...           Neutral
# 8   In addition to these steps, we took forceful m...          Positive
# 9   For the past year and a half, my colleagues an...           Neutral
# 10  The Main Street Lending Program The Federal Re...          Positive
# 11  We identified three ways that our tools could ...           Neutral
# 12  We published a set of key principles to guide ...          Positive
# 13  The Primary Market Corporate Credit Facility T...          Positive
#
#     nasdaq_Pct_Change  sp500_Pct_Change
# 0           -0.433328         -0.241245
# 1           -0.188881          0.462011
# 2           -2.412975         -2.360265
# 3           -1.586488         -1.600218
# 4           -0.459065         -0.869907
# 5           -0.963293         -0.721898
# 6           -0.541823         -0.199936
# 7           -0.956070         -1.354970
# 8            1.857966          1.642187
# 9           -0.537727         -0.016929
# 10           0.830841          0.601381
# 11          -1.413498         -1.401398
# 12          -0.590066          0.064065
# 13           0.339063          0.454761
